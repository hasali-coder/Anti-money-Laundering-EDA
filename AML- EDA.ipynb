# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import plotly.express as px 
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\CMuasya'

# %%
aml = pd.read_csv("C:\\Users\\CMuasya\\downloads\\aml_sample.csv")

# %%
aml.head()
# Out:
#    DOCTYPE  AON  STATUS  age  last  reg_loc       sum      avg  sum_imt  \
# 0        1    1       0   35     1        1    4418.0    883.6      0.0
# 1        1    1       0   35     1        1     693.0    138.6      0.0
# 2        1    1       0   31     1        1   12544.0   1792.0      0.0
# 3        1    1       0   59     1        1  135900.0  27180.0      0.0
# 4        1    1       0   27     1        1     500.0    500.0      0.0
#
#    avg_imt  ...  no_trxn    stddev_amt  stddev_imt     stddev_cr  \
# 0      0.0  ...       15    850.002823         0.0    828.799614
# 1      0.0  ...       12    103.410831         0.0    109.544511
# 2      0.0  ...       75   2444.013843         0.0   2319.615393
# 3      0.0  ...       18  34250.959840         0.0  33295.052180
# 4      0.0  ...        1           NaN         NaN           NaN
#
#       stddev_dr  stddev_trxn  CNTRY_count  IMEI  PRIM_LINE  cal_tfr_sspect
# ...

# %%
aml.isnull().sum()
# Out:
# DOCTYPE                0
# AON                    0
# STATUS                 0
# age                    0
# last                   0
# reg_loc                0
# sum                    0
# avg                    0
# sum_imt                0
# avg_imt                0
# sum_cr                 0
# avg_cr                 0
# sum_dr                 0
# avg_dr                 0
# no_trxn                0
# stddev_amt          5449
# stddev_imt          5449
# stddev_cr           5449
# stddev_dr           5449
# stddev_trxn         5449
# CNTRY_count       100000
# IMEI                   0
# PRIM_LINE              0
# cal_tfr_sspect         0
# dtype: int64

# %%
aml.columns
# Out:
# Index(['DOCTYPE', 'AON', 'STATUS', 'age', 'last', 'reg_loc', 'sum', 'avg',
#        'sum_imt', 'avg_imt', 'sum_cr', 'avg_cr', 'sum_dr', 'avg_dr', 'no_trxn',
#        'stddev_amt', 'stddev_imt', 'stddev_cr', 'stddev_dr', 'stddev_trxn',
#        'IMEI', 'PRIM_LINE', 'cal_tfr_sspect'],
#       dtype='object')

# %%
aml.isnull().sum()
# Out:
# DOCTYPE              0
# AON                  0
# STATUS               0
# age                  0
# last                 0
# reg_loc              0
# sum                  0
# avg                  0
# sum_imt              0
# avg_imt              0
# sum_cr               0
# avg_cr               0
# sum_dr               0
# avg_dr               0
# no_trxn              0
# stddev_amt        5449
# stddev_imt        5449
# stddev_cr         5449
# stddev_dr         5449
# stddev_trxn       5449
# IMEI                 0
# PRIM_LINE            0
# cal_tfr_sspect       0
# dtype: int64

# %%
aml = aml.fillna(0)

# %%
aml.isnull().sum()
# Out:
# DOCTYPE           0
# AON               0
# STATUS            0
# age               0
# last              0
# reg_loc           0
# sum               0
# avg               0
# sum_imt           0
# avg_imt           0
# sum_cr            0
# avg_cr            0
# sum_dr            0
# avg_dr            0
# no_trxn           0
# stddev_amt        0
# stddev_imt        0
# stddev_cr         0
# stddev_dr         0
# stddev_trxn       0
# IMEI              0
# PRIM_LINE         0
# cal_tfr_sspect    0
# dtype: int64

# %%
df = aml

# %%
df.nunique()
# Out:
# DOCTYPE               5
# AON                  39
# STATUS                4
# age                  99
# last                 12
# reg_loc               2
# sum               50567
# avg               57846
# sum_imt            1835
# avg_imt            2042
# sum_cr            28591
# avg_cr            38146
# sum_dr            42739
# avg_dr            50639
# no_trxn             653
# stddev_amt        70850
# stddev_imt         2072
# stddev_cr         60754
# stddev_dr         70205
# stddev_trxn       18814
# IMEI                  2
# PRIM_LINE             2
# cal_tfr_sspect       13
# dtype: int64

# %%
df['cal_tfr_sspect'].unique()
# Out:
# array([ 0,  1,  2, 23, 21,  4,  3,  7,  5, 10, 14, 11, 15], dtype=int64)

# %%
df['PRIM_LINE'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['IMEI'].unique()
# Out:
# array([0, 2], dtype=int64)

# %%
df['reg_loc'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['last'].unique()
# Out:
# array([ 1,  9,  3, 10,  2,  4, -4,  8,  5,  6,  7, 20], dtype=int64)

# %%
df['STATUS'].unique()
# Out:
# array([0, 1, 3, 2], dtype=int64)

# %%
df['AON'].unique()
# Out:
# array([  1,   9,   2,  10,   3,   6,   5,   7,   8,   4,  -1,  -5,  20,
#         -3,  -6,  18,  11,  12,  -7,  72,  17,  13,  78,  55,  73,  -2,
#         76,  14,  15,  79,  74,  44, -18,  28,  35,  75,  77, -17,  53],
#       dtype=int64)

# %%
df['IMEI'].unique()
# Out:
# array([0, 2], dtype=int64)

# %%
correlation = df.corr()

# %%
fig, ax = plt.subplots(figsize=(25,25))
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df['AON'])
# Out:
# C:\Users\CMuasya\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AON'>

# %%
df['AON'].describe()
# Out:
# count    100000.00000
# mean          4.91577
# std           4.58233
# min         -18.00000
# 25%           1.00000
# 50%           5.00000
# 75%           9.00000
# max          79.00000
# Name: AON, dtype: float64

# %%
df['AON'] = np.where(df['AON']>=9, 9, df['AON'])

# %%
sns.boxplot(df['AON'])
# Out:
# C:\Users\CMuasya\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AON'>

# %%
df['AON'] = np.where(df['AON']<=1, 1, df['AON'])

# %%
sns.boxplot(df['AON'])
# Out:
# C:\Users\CMuasya\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AON'>

# %%
df['age'].describe()
# Out:
# count    100000.000000
# mean         37.915370
# std          14.893665
# min         -19.000000
# 25%          27.000000
# 50%          35.000000
# 75%          47.000000
# max          80.000000
# Name: age, dtype: float64

# %%
sns.boxplot(df['age'])
# Out:
# C:\Users\CMuasya\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
df['age'] = np.where(df['age']<27, 27, df['age'])

# %%
df['age'] = np.where(df['age']>47, 47, df['age'])

# %%
sns.boxplot(df['age'])
# Out:
# C:\Users\CMuasya\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
df.describe()
# Out:
#             DOCTYPE            AON         STATUS            age  \
# count  100000.00000  100000.000000  100000.000000  100000.000000
# mean        1.04038       4.804540       0.677560      36.384090
# std         0.29249       3.306827       0.977999       8.136152
# min         0.00000       1.000000       0.000000      27.000000
# 25%         1.00000       1.000000       0.000000      27.000000
# 50%         1.00000       5.000000       0.000000      35.000000
# 75%         1.00000       9.000000       1.000000      47.000000
# max         4.00000       9.000000       3.000000      47.000000
#
#                 last        reg_loc           sum           avg       sum_imt  \
# count  100000.000000  100000.000000  1.000000e+05  1.000000e+05  1.000000e+05
# mean        5.092200       0.995180  7.513901e+04  1.039919e+04  1.025077e+03
# std         3.680437       0.069259  3.782726e+05  5.874705e+04  1.475865e+04
# ...

# %%
import plotly.express as px

# %%
plt.figure(figsize = [10,5])
sns.countplot(df['PRIM_LINE'],hue=df['cal_tfr_sspect'], palette=('#1e847f', '#ecc19c', '#000000'))
plt.legend(loc='upper right')
plt.title('Primary Line versus the Dected Fraudsters',fontsize=20)
plt.xlabel('Primary Line', fontsize=16)
plt.ylabel('Call Traffic', fontsize=16)
plt.show()
# Out:
# C:\Users\CMuasya\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
df['age'].unique()
# Out:
# array([35, 31, 47, 27, 38, 30, 28, 37, 46, 34, 32, 40, 41, 44, 42, 29, 36,
#        39, 33, 45, 43], dtype=int64)

# %%
df['cal_tfr_sspect'].unique()
# Out:
# array([ 0,  1,  2, 23, 21,  4,  3,  7,  5, 10, 14, 11, 15], dtype=int64)

# %%
df['AON'].unique()
# Out:
# array([1, 9, 2, 3, 6, 5, 7, 8, 4], dtype=int64)

# %%
plt.figure(figsize = [18,7])
sns.countplot(df['age'],hue=df['cal_tfr_sspect'],palette=('#1e847f', '#ecc19c', '#000000'))
plt.legend(loc='upper left')
plt.title('Age vs Fraud Suspect',fontsize=20)
plt.xlabel('Age', fontsize=16)
plt.ylabel('Call tarrif suspect', fontsize=16)
plt.show()
# Out:
# C:\Users\CMuasya\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
df['AON'].unique()
# Out:
# array([1, 9, 2, 3, 6, 5, 7, 8, 4], dtype=int64)

# %%
plt.figure(figsize = [20,15])
sns.countplot(df['age'],hue=df['PRIM_LINE'])
plt.title('Different age grps with primary lines comparison',fontsize=20)
plt.xlabel('Primary Line', fontsize=16)
plt.ylabel('Count on Primary Lines', fontsize=16)
plt.show()
# Out:
# C:\Users\CMuasya\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
df['STATUS'].unique()
# Out:
# array([0, 1, 3, 2], dtype=int64)

# %%
plt.figure(figsize = [10,5])
sns.countplot(df['PRIM_LINE'],hue=df['STATUS'])
plt.legend(loc='upper right')
plt.title('Primary Line versus the Status',fontsize=20)
plt.xlabel('Primary Line', fontsize=16)
plt.ylabel('Status', fontsize=16)
plt.show()
# Out:
# C:\Users\CMuasya\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.figure(figsize = [15,12])
sns.countplot(df['age'],hue=df['AON'])
plt.legend(loc='upper right')
plt.title('AON comparison with different age groups',fontsize=20)
plt.xlabel('Age Group', fontsize=16)
plt.ylabel('Status', fontsize=16)
plt.show()
# Out:
# C:\Users\CMuasya\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
df.nunique()
# Out:
# DOCTYPE               5
# AON                   9
# STATUS                4
# age                  21
# last                 12
# reg_loc               2
# sum               50567
# avg               57846
# sum_imt            1835
# avg_imt            2042
# sum_cr            28591
# avg_cr            38146
# sum_dr            42739
# avg_dr            50639
# no_trxn             653
# stddev_amt        70850
# stddev_imt         2072
# stddev_cr         60754
# stddev_dr         70205
# stddev_trxn       18814
# IMEI                  2
# PRIM_LINE             2
# cal_tfr_sspect       13
# dtype: int64

# %%
df.head()
# Out:
#    DOCTYPE  AON  STATUS  age  last  reg_loc       sum      avg  sum_imt  \
# 0        1    1       0   35     1        1    4418.0    883.6      0.0
# 1        1    1       0   35     1        1     693.0    138.6      0.0
# 2        1    1       0   31     1        1   12544.0   1792.0      0.0
# 3        1    1       0   47     1        1  135900.0  27180.0      0.0
# 4        1    1       0   27     1        1     500.0    500.0      0.0
#
#    avg_imt  ...        avg_dr  no_trxn    stddev_amt  stddev_imt  \
# 0      0.0  ...    436.000000       15    850.002823         0.0
# 1      0.0  ...     68.600000       12    103.410831         0.0
# 2      0.0  ...    898.714286       75   2444.013843         0.0
# 3      0.0  ...  12290.000000       18  34250.959840         0.0
# 4      0.0  ...    500.000000        1      0.000000         0.0
#
#       stddev_cr     stddev_dr  stddev_trxn  IMEI  PRIM_LINE  cal_tfr_sspect
# ...

# %%
plt.figure(figsize = [15,12])
sns.countplot(df['AON'],hue=df['PRIM_LINE'])
plt.legend(loc='upper right')
plt.title('AON aganist PRIM LINES',fontsize=20)
plt.xlabel('AON ', fontsize=16)
plt.ylabel('PRIM LINE', fontsize=16)
plt.show()
# Out:
# C:\Users\CMuasya\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
imei_trxn = df.groupby('PRIM_LINE')['no_trxn']

# %%
prim_grpd = df.groupby('PRIM_LINE')['no_trxn'].count()

# %%
prim_grpd
# Out:
# PRIM_LINE
# 0     7293
# 1    92707
# Name: no_trxn, dtype: int64

# %%
prim_grpd.to_frame
# Out:
# <bound method Series.to_frame of PRIM_LINE
# 0     7293
# 1    92707
# Name: no_trxn, dtype: int64>

# %%
# %matplotlib inline
plt.figure(figsize = [12,10])

plt.style.use('ggplot')

prim_line = ['0', '1']
count_no_trxn = [7293, 92707]

x_pos = [i for i, _ in enumerate(prim_line)]

plt.bar(x_pos, count_no_trxn, color='green')
plt.xlabel("PRMARY LINE")
plt.ylabel("Number of Transactions")
plt.title("No of transactions in different forms of the Primary Line")

plt.xticks(x_pos, prim_line)

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DOCTYPE         100000 non-null  int64
#  1   AON             100000 non-null  int64
#  2   STATUS          100000 non-null  int64
#  3   age             100000 non-null  int64
#  4   last            100000 non-null  int64
#  5   reg_loc         100000 non-null  int64
#  6   sum             100000 non-null  float64
#  7   avg             100000 non-null  float64
#  8   sum_imt         100000 non-null  float64
#  9   avg_imt         100000 non-null  float64
#  10  sum_cr          100000 non-null  float64
#  11  avg_cr          100000 non-null  float64
#  12  sum_dr          100000 non-null  float64
#  13  avg_dr          100000 non-null  float64
#  14  no_trxn         100000 non-null  int64
#  15  stddev_amt      100000 non-null  float64
# ...

# %%
#trend between cal_tfr_sspect and no_trxn
plt.figure(figsize=(19,13))
sns.jointplot(x="cal_tfr_sspect", y="no_trxn", data=df)

# %%
plt.figure(figsize=(11,7))
sns.countplot(x='STATUS', hue="PRIM_LINE", data=df)
# Out:
# <AxesSubplot:xlabel='STATUS', ylabel='count'>

# %%
plt.figure(figsize=(11,7))
plt.hist(df['age'])
# Out:
# (array([28892.,  6647.,  7148.,  6689.,  5788.,  4302.,  3276.,  3528.,
#          3888., 29842.]),
#  array([27., 29., 31., 33., 35., 37., 39., 41., 43., 45., 47.]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(11,7))
sns.barplot(df['IMEI'],df['no_trxn'])
# Out:
# C:\Users\CMuasya\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='IMEI', ylabel='no_trxn'>

# %%
plt.figure(figsize=(11,7))
sns.barplot(df['PRIM_LINE'], df['cal_tfr_sspect'])
# Out:
# C:\Users\CMuasya\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='PRIM_LINE', ylabel='cal_tfr_sspect'>

# %%
plt.figure(figsize=(11,7))
sns.distplot(df['no_trxn'])
# Out:
# C:\Users\CMuasya\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='no_trxn', ylabel='Density'>

# %%
correlation = df.corr()

# %%
plt.figure(figsize=(11,7))
sns.heatmap(correlation)
# Out:
# <AxesSubplot:>
